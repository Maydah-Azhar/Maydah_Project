# %%
#Greeting
print('Assalam o alaikum')
print('Hope you are doing good')
# Out:
# Assalam o alaikum
# Hope you are doing good

# %% [markdown]
# $$
# Install-libraries
# $$

# %%
pip install pandas seaborn matplotlib numpy

# %% [markdown]
# $$
# Importing
# $$

# %%
import seaborn as sns
import matplotlib as plt    
import pandas as pd
import numpy as np

# %% [markdown]
# $$
# Explanation-of-Data:
# $$
#
# This dataset is webscrapped and pdf-to-csv converted data, which is organised and cleaned prior and only requires rows are gathered and exported. This includes various Fast Food Chain Giants like KFC, McDonald's, Burger King, Dominos, Pizza Hut and Starbucks.
#
# The columns are as follows:
#
# Company - Name of the Fast Food Company.
#
# Category - The category of the meal
#
# Product - Name of the Meal
#
# Per Serve Size - Quantity of the Meal Served
#
# Energy (kCal) - Energy from the Meal in Kilo Calories
#
# Carbohydrates (g) - Carbohydrates obtained from the Meal in grams
#
# Protein (g) - Proteins obtained from the Meal in grams
#
# Fiber (g) - Fibers obtained from the Meal in grams
#
# Sugar (g) - Sugars obtained from the Meal in grams
#
# Total Fat (g) - Total Fats obtained from the Meal in grams
#
# Saturated Fat (g) - Saturated Fats obtained from the Meal in grams
#
# Trans Fat (g) - Trans Fat obtained from the Meal in grams
#
# Cholesterol (mg) - Cholesterol obtained from the Meal in
#
# Sodium (mg) - Sodium obtained from the Meal in grams

# %% [markdown]
# # Which variables you used for study and why?
# $$

# %% [markdown]
# Company: Pizza Hut, Burger King, Starbucks, McDonalds, KFC.
#
# Category: All meals, Hot Breakfast, Cookies, Brownies & Bars, Croissants, Danishes & Bagels, Loaves, Coffee Cakes & Cake Pops, Seasonal Bakery Offerings, Fruit & Yogurt, REGULAR MENU, BREAKFAST MENU, McCAFE MENU, DESSERTS MENU, GOURMET MENU, CONDIMENTS MENU.
#
# Products: The product variable contains all the products that these company serves.
#
# Carbohydrates (g), Sugar (g), Proteins (g) are the variables i used for comparisons and to plot the graphs because these three are most important in any meal.

# %% [markdown]
# $$
# Count-plot
# $$

# %%
sns.countplot(x=x["Company"],saturation=0.9)
# Out:
# <AxesSubplot: xlabel='Company', ylabel='count'>

# %% [markdown]
# **Interpretation**
# 1. Pizza Hut has the maximum number of products.
# 2. Burger King has the least count of products
#
# **Ratio**
# 1. 27.35% Pizza hut
# 2. 7.54% Burger King
# 3. 8.67% Starbucks
# 4. 26.22% McDonalds
# 5. 13.39% KFC
# 6.  Dominos

# %%
sns.countplot(y= x["Company"], hue=x["Category"],saturation = 1)
# Out:
# <AxesSubplot: xlabel='count', ylabel='Company'>

# %% [markdown]
# **Interpretation**
# 1. Pizza Hut, Burger King, Dominos, KFC has all meals.
# 2. Starbucks, Mcdonalds have less meals

# %% [markdown]
# $$
# Scatter-plot
# $$

# %%
sns.scatterplot(data = x, x='Company',y="Category")
# Out:
# <AxesSubplot: xlabel='Company', ylabel='Category'>

# %%
sns.scatterplot(data = x, x='Company',y="Sugar (g)")
# Out:
# <AxesSubplot: xlabel='Company', ylabel='Sugar (g)'>

# %%
sns.scatterplot(data = x, x='Company',y="Carbohydrates (g)")
# Out:
# <AxesSubplot: xlabel='Company', ylabel='Carbohydrates (g)'>

# %% [markdown]
# Scatterplot with correlation

# %%
sns.scatterplot(data = x, x="Carbohydrates (g)",y="Sugar (g)",hue="Category",palette=['pink','red','yellow','blue','green','black','orange','purple','brown'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12552\1294668050.py:1: UserWarning:
# The palette list has fewer values (9) than needed (13) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data = x, x="Carbohydrates (g)",y="Sugar (g)",hue="Category",palette=['pink','red','yellow','blue','green','black','orange','purple','brown'])
# <AxesSubplot: xlabel='Carbohydrates (g)', ylabel='Sugar (g)'>

# %% [markdown]
# $$
# Box-plot
# $$

# %%
sns.boxplot(data = x,y="Protein (g)",palette='Set1')
# Out:
# <AxesSubplot: ylabel='Protein (g)'>

# %%
sns.boxplot(data = x,y="Carbohydrates (g)",palette='Dark2')
# Out:
# <AxesSubplot: ylabel='Carbohydrates (g)'>

# %% [markdown]
# **Box-plot with Mean line**

# %%
#group chart of Sugar in all companies
sns.boxplot(data = x, x='Company',y='Sugar (g)',showmeans= True,)
# Out:
# <AxesSubplot: xlabel='Company', ylabel='Sugar (g)'>

# %%
sns.boxplot(data = x, x='Company',y='Protein (g)',showmeans=True)
# Out:
# <AxesSubplot: xlabel='Company', ylabel='Protein (g)'>

# %% [markdown]
# **Boxplot with swarmplot**

# %%
sns.boxplot(data = x, x='Company',y='Sugar (g)',showmeans= True,)
sns.swarmplot(data = x, x='Company',y='Sugar (g)', size=3, color='black')
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 65.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 34.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 20.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='Company', ylabel='Sugar (g)'>

# %% [markdown]
# $$
# Histogram
# $$

# %%
sns.histplot(data=x, x='Carbohydrates (g)',palette='Dark2')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12552\1497856007.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=x, x='Carbohydrates (g)',palette='Dark2')
# <AxesSubplot: xlabel='Carbohydrates (g)', ylabel='Count'>

# %%
sns.histplot(data=x, x='Protein (g)')
# Out:
# <AxesSubplot: xlabel='Protein (g)', ylabel='Count'>

# %% [markdown]
# **Histogram with Trend line**

# %%
sns.histplot(data=x, x="Carbohydrates (g)", kde=True)
# Out:
# <AxesSubplot: xlabel='Carbohydrates (g)', ylabel='Count'>

# %%
sns.histplot(data=x, x="Sugar (g)", kde=True)
# Out:
# <AxesSubplot: xlabel='Sugar (g)', ylabel='Count'>

# %% [markdown]
# **Simple linear Line graph**

# %%
sns.lmplot( data=x, x='Sugar (g)',y='Carbohydrates (g)',hue='Category',row='Company', palette='Dark2')

# %% [markdown]
# $$
# Exploratory-Data-Analysis
# $$

# %% [markdown]
# ### Introduction:
# Exploratory data analysis (EDA) is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods. The goal is to explore, investigate and learn, as opposed to confirming statistical hypotheses.

# %% [markdown]
# ### To read the data

# %%
import pandas as pd

x=pd.read_csv("Nutrition_Value_Dataset (1).csv")
x

# %% [markdown]
# ### To know about the Rows and Columns

# %%
x.shape
# Out:
# (530, 14)

# %% [markdown]
# ### T display the first 5 rows

# %%
x.head()

# %% [markdown]
# ### To display the last 5 rows

# %%
x.tail()

# %% [markdown]
# ### Basic Information about the Data

# %%
#to know about every variables with its info
x.info

# %%
#to find number of rows and coloumns
x.shape
# Out:
# (530, 14)

# %%
## To know about data presence
print(os.listdir())
# Out:
# ['Maydah_project.ipynb', 'Nutrition_Value_Dataset (1).csv', 'project.ipynb']

# %%
#To describe the data
x.describe

# %% [markdown]
# ###  NULL values

# %%
#to identify NULL values
x.isnull().values.any()
# Out:
# True

# %%
#TO detect NULL values
x.isnull().sum()

# %%
#To remove NULL values
x.fillna(0)

# %% [markdown]
# ### Value Count Function

# %%
x["Per Serve Size"].value_counts()

# %%
x["Company"].value_counts()

# %% [markdown]
# ### Duplicates values

# %%
x.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### To know about Datatypes

# %%
x.dtypes

# %%
x[['Sugar (g)']].boxplot()
# Out:
# <AxesSubplot: >
